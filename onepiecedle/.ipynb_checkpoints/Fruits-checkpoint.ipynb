# %%
import pandas as pd

# %%
char_df = pd.read_excel("one_piece_characters.xlsx")
fruits_df = pd.read_excel("onepiece_fruit.xlsx")

# %%
fruits_df.head()
# Out:
#               Name      Translation       Type             User  \
# 0  Gomu Gomu no Mi    Gum-Gum Fruit  Paramecia  Monkey D. Luffy
# 1  Bara Bara no Mi  Chop-Chop Fruit  Paramecia            Buggy
# 2  Sube Sube no Mi  Slip-Slip Fruit  Paramecia           Alvida
# 3  Bomu Bomu no Mi  Boom-Boom Fruit  Paramecia       Gem (Mr.5)
# 4  Kiro Kiro no Mi  Kilo-Kilo Fruit  Paramecia   Miss Valentine
#
#                Usage Debut                                              Usage
# 0     Chapter 1; Episode 1  Turns the user's body into rubber, giving them...
# 1     Chapter 9; Episode 5  Allows the user to split their body into separ...
# 2   Chapter 51; Episode 46  It makes the user's body smooth and slippery, ...
# 3  Chapter 110; Episode 65  It allows the user to make any part of their b...
# 4  Chapter 112; Episode 66  It allows the user to change their weight from...

# %%
char_df.head()
# Out:
#               Name               Image  Gender  Age Devil Fruit  Last Bounty  \
# 0  Monkey D. Luffy  monkey_d_luffy.jpg    Male   19        Zoan   3000000000
# 1     Roronoa Zoro    roronoa_zoro.jpg    Male   21           X   1100000000
# 2   Vinsmoke Sanji  vinsmoke_sanji.jpg    Male   21           X   1000000000
# 3             Nami            nami.jpg  Female   20           X    366000000
# 4       Nico Robin      nico_robin.jpg  Female   30   Paramecia    930000000
#
#       Debut Arc    Haki        Affiliation      Episode  Arc Index
# 0  Romance Dawn     All  Straw Hat Pirates    Episode 1          0
# 1  Romance Dawn     All  Straw Hat Pirates    Episode 1          0
# 2       Baratie  ArmObs  Straw Hat Pirates   Episode 20          3
# 3   Orange Town       X  Straw Hat Pirates    Episode 1          1
# 4  Whiskey Peak       X  Straw Hat Pirates   Episode 67          7

# %%
for i in char_df["Name"]:
    for j in fruits_df["User"]:
        if i == j:
            print(i)
        else:
            pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for i in char_df["User"]:
# ...
